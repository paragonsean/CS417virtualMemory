# %%
import numpy as np
import pandas as pd

def lru_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    recent_usage = []
    print(f"--- LRU Page Replacement with {num_frames} frames ---")
    for page in pages:
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                # Remove the least recently used page
                lru_page = recent_usage.pop(0)
                index = frames.index(lru_page)
                frames[index] = page
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")

        # Update recent usage
        if page in recent_usage:
            recent_usage.remove(page)
        recent_usage.append(page)
    print(f"Total faults for LRU: {page_faults}\n")
    return page_faults

def fifo_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    print(f"--- FIFO Page Replacement with {num_frames} frames ---")
    for page in pages:
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                frames.pop(0)  # Remove the oldest page
                frames.append(page)
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")
    print(f"Total faults for FIFO: {page_faults}\n")
    return page_faults

def optimal_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    print(f"--- Optimal Page Replacement with {num_frames} frames ---")
    for i, page in enumerate(pages):
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                # Determine which page in frames is used farthest in the future
                future_use = {
                    frame: (pages[i+1:].index(frame) if frame in pages[i+1:] else float('inf'))
                    for frame in frames
                }
                frame_to_replace = max(future_use, key=future_use.get)
                index = frames.index(frame_to_replace)
                frames[index] = page
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")
    print(f"Total faults for Optimal: {page_faults}\n")
    return page_faults

# Given page reference string
pages = [0, 3, 5, 1, 1, 2, 5, 4, 3, 2, 1, 2, 5, 4, 6, 7, 5, 4, 7, 8, 9, 10, 5, 6, 10, 1, 2, 3]

# Frame sizes from 1 to 6 (inclusive)
frame_sizes = range(1, 7)

# Calculate page faults for each algorithm and frame size
lru_faults = {}
fifo_faults = {}
optimal_faults = {}

for frames in frame_sizes:
    lru_faults[frames] = lru_page_replacement(pages, frames)
    fifo_faults[frames] = fifo_page_replacement(pages, frames)
    optimal_faults[frames] = optimal_page_replacement(pages, frames)

# Create a DataFrame to display summary results
df_results = pd.DataFrame({
    "Frames": list(frame_sizes),
    "LRU Faults": [lru_faults[f] for f in frame_sizes],
    "FIFO Faults": [fifo_faults[f] for f in frame_sizes],
    "Optimal Faults": [optimal_faults[f] for f in frame_sizes]
})

print("Summary of Page Faults:")
print(df_results)
import numpy as np
import pandas as pd

def lru_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    recent_usage = []
    print(f"--- LRU Page Replacement with {num_frames} frames ---")
    for page in pages:
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                # Remove the least recently used page
                lru_page = recent_usage.pop(0)
                index = frames.index(lru_page)
                frames[index] = page
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")

        # Update recent usage
        if page in recent_usage:
            recent_usage.remove(page)
        recent_usage.append(page)
    print(f"Total faults for LRU: {page_faults}\n")
    return page_faults

def fifo_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    print(f"--- FIFO Page Replacement with {num_frames} frames ---")
    for page in pages:
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                frames.pop(0)  # Remove the oldest page
                frames.append(page)
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")
    print(f"Total faults for FIFO: {page_faults}\n")
    return page_faults

def optimal_page_replacement(pages, num_frames):
    frames = []
    page_faults = 0
    print(f"--- Optimal Page Replacement with {num_frames} frames ---")
    for i, page in enumerate(pages):
        if page not in frames:
            if len(frames) < num_frames:
                frames.append(page)
            else:
                # Determine which page in frames is used farthest in the future
                future_use = {
                    frame: (pages[i+1:].index(frame) if frame in pages[i+1:] else float('inf'))
                    for frame in frames
                }
                frame_to_replace = max(future_use, key=future_use.get)
                index = frames.index(frame_to_replace)
                frames[index] = page
            page_faults += 1
            print(f"Page {page}: Fault occurred. Frames: {frames}")
        else:
            print(f"Page {page}: No fault. Frames: {frames}")
    print(f"Total faults for Optimal: {page_faults}\n")
    return page_faults

# Given page reference string
pages = [1, 2, 3, 4, 2, 1, 5, 6, 2, 1, 2, 3, 7, 6, 3, 2, 1, 2, 3, 6]

# Frame sizes from 1 to 7 (inclusive)
frame_sizes = range(1, 8)

# Calculate page faults for each algorithm and frame size
lru_faults = {}
fifo_faults = {}
optimal_faults = {}

for frames in frame_sizes:
    lru_faults[frames] = lru_page_replacement(pages, frames)
    fifo_faults[frames] = fifo_page_replacement(pages, frames)
    optimal_faults[frames] = optimal_page_replacement(pages, frames)

# Create a DataFrame to display summary results
df_results = pd.DataFrame({
    "Frames": list(frame_sizes),
    "LRU Faults": [lru_faults[f] for f in frame_sizes],
    "FIFO Faults": [fifo_faults[f] for f in frame_sizes],
    "Optimal Faults": [optimal_faults[f] for f in frame_sizes]
})

print("Summary of Page Faults:")
print(df_results)
# Out:
# --- LRU Page Replacement with 1 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [3]
# Page 5: Fault occurred. Frames: [5]
# Page 1: Fault occurred. Frames: [1]
# Page 1: No fault. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 6: Fault occurred. Frames: [6]
# Page 7: Fault occurred. Frames: [7]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 7: Fault occurred. Frames: [7]
# Page 8: Fault occurred. Frames: [8]
# Page 9: Fault occurred. Frames: [9]
# Page 10: Fault occurred. Frames: [10]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 10: Fault occurred. Frames: [10]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Total faults for LRU: 27
#
# --- FIFO Page Replacement with 1 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [3]
# Page 5: Fault occurred. Frames: [5]
# Page 1: Fault occurred. Frames: [1]
# Page 1: No fault. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 6: Fault occurred. Frames: [6]
# Page 7: Fault occurred. Frames: [7]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 7: Fault occurred. Frames: [7]
# Page 8: Fault occurred. Frames: [8]
# Page 9: Fault occurred. Frames: [9]
# Page 10: Fault occurred. Frames: [10]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 10: Fault occurred. Frames: [10]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Total faults for FIFO: 27
#
# --- Optimal Page Replacement with 1 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [3]
# Page 5: Fault occurred. Frames: [5]
# Page 1: Fault occurred. Frames: [1]
# Page 1: No fault. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 6: Fault occurred. Frames: [6]
# Page 7: Fault occurred. Frames: [7]
# Page 5: Fault occurred. Frames: [5]
# Page 4: Fault occurred. Frames: [4]
# Page 7: Fault occurred. Frames: [7]
# Page 8: Fault occurred. Frames: [8]
# Page 9: Fault occurred. Frames: [9]
# Page 10: Fault occurred. Frames: [10]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 10: Fault occurred. Frames: [10]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Total faults for Optimal: 27
#
# --- LRU Page Replacement with 2 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [5, 3]
# Page 1: Fault occurred. Frames: [5, 1]
# Page 1: No fault. Frames: [5, 1]
# Page 2: Fault occurred. Frames: [2, 1]
# Page 5: Fault occurred. Frames: [2, 5]
# Page 4: Fault occurred. Frames: [4, 5]
# Page 3: Fault occurred. Frames: [4, 3]
# Page 2: Fault occurred. Frames: [2, 3]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 2: No fault. Frames: [2, 1]
# Page 5: Fault occurred. Frames: [2, 5]
# Page 4: Fault occurred. Frames: [4, 5]
# Page 6: Fault occurred. Frames: [4, 6]
# Page 7: Fault occurred. Frames: [7, 6]
# Page 5: Fault occurred. Frames: [7, 5]
# Page 4: Fault occurred. Frames: [4, 5]
# Page 7: Fault occurred. Frames: [4, 7]
# Page 8: Fault occurred. Frames: [8, 7]
# Page 9: Fault occurred. Frames: [8, 9]
# Page 10: Fault occurred. Frames: [10, 9]
# Page 5: Fault occurred. Frames: [10, 5]
# Page 6: Fault occurred. Frames: [6, 5]
# Page 10: Fault occurred. Frames: [6, 10]
# Page 1: Fault occurred. Frames: [1, 10]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Total faults for LRU: 26
#
# --- FIFO Page Replacement with 2 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [3, 5]
# Page 1: Fault occurred. Frames: [5, 1]
# Page 1: No fault. Frames: [5, 1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 5: Fault occurred. Frames: [2, 5]
# Page 4: Fault occurred. Frames: [5, 4]
# Page 3: Fault occurred. Frames: [4, 3]
# Page 2: Fault occurred. Frames: [3, 2]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 2: No fault. Frames: [2, 1]
# Page 5: Fault occurred. Frames: [1, 5]
# Page 4: Fault occurred. Frames: [5, 4]
# Page 6: Fault occurred. Frames: [4, 6]
# Page 7: Fault occurred. Frames: [6, 7]
# Page 5: Fault occurred. Frames: [7, 5]
# Page 4: Fault occurred. Frames: [5, 4]
# Page 7: Fault occurred. Frames: [4, 7]
# Page 8: Fault occurred. Frames: [7, 8]
# Page 9: Fault occurred. Frames: [8, 9]
# Page 10: Fault occurred. Frames: [9, 10]
# Page 5: Fault occurred. Frames: [10, 5]
# Page 6: Fault occurred. Frames: [5, 6]
# Page 10: Fault occurred. Frames: [6, 10]
# Page 1: Fault occurred. Frames: [10, 1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [2, 3]
# Total faults for FIFO: 26
#
# --- Optimal Page Replacement with 2 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [5, 3]
# Page 1: Fault occurred. Frames: [5, 1]
# Page 1: No fault. Frames: [5, 1]
# Page 2: Fault occurred. Frames: [5, 2]
# Page 5: No fault. Frames: [5, 2]
# Page 4: Fault occurred. Frames: [4, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 2: No fault. Frames: [3, 2]
# Page 1: Fault occurred. Frames: [1, 2]
# Page 2: No fault. Frames: [1, 2]
# Page 5: Fault occurred. Frames: [1, 5]
# Page 4: Fault occurred. Frames: [4, 5]
# Page 6: Fault occurred. Frames: [6, 5]
# Page 7: Fault occurred. Frames: [7, 5]
# Page 5: No fault. Frames: [7, 5]
# Page 4: Fault occurred. Frames: [7, 4]
# Page 7: No fault. Frames: [7, 4]
# Page 8: Fault occurred. Frames: [8, 4]
# Page 9: Fault occurred. Frames: [9, 4]
# Page 10: Fault occurred. Frames: [10, 4]
# Page 5: Fault occurred. Frames: [10, 5]
# Page 6: Fault occurred. Frames: [10, 6]
# Page 10: No fault. Frames: [10, 6]
# Page 1: Fault occurred. Frames: [1, 6]
# Page 2: Fault occurred. Frames: [2, 6]
# Page 3: Fault occurred. Frames: [3, 6]
# Total faults for Optimal: 21
#
# --- LRU Page Replacement with 3 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [1, 3, 5]
# Page 1: No fault. Frames: [1, 3, 5]
# Page 2: Fault occurred. Frames: [1, 2, 5]
# Page 5: No fault. Frames: [1, 2, 5]
# Page 4: Fault occurred. Frames: [4, 2, 5]
# Page 3: Fault occurred. Frames: [4, 3, 5]
# Page 2: Fault occurred. Frames: [4, 3, 2]
# Page 1: Fault occurred. Frames: [1, 3, 2]
# Page 2: No fault. Frames: [1, 3, 2]
# Page 5: Fault occurred. Frames: [1, 5, 2]
# Page 4: Fault occurred. Frames: [4, 5, 2]
# Page 6: Fault occurred. Frames: [4, 5, 6]
# Page 7: Fault occurred. Frames: [4, 7, 6]
# Page 5: Fault occurred. Frames: [5, 7, 6]
# Page 4: Fault occurred. Frames: [5, 7, 4]
# Page 7: No fault. Frames: [5, 7, 4]
# Page 8: Fault occurred. Frames: [8, 7, 4]
# Page 9: Fault occurred. Frames: [8, 7, 9]
# Page 10: Fault occurred. Frames: [8, 10, 9]
# Page 5: Fault occurred. Frames: [5, 10, 9]
# Page 6: Fault occurred. Frames: [5, 10, 6]
# Page 10: No fault. Frames: [5, 10, 6]
# Page 1: Fault occurred. Frames: [1, 10, 6]
# Page 2: Fault occurred. Frames: [1, 10, 2]
# Page 3: Fault occurred. Frames: [1, 3, 2]
# Total faults for LRU: 23
#
# --- FIFO Page Replacement with 3 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [3, 5, 1]
# Page 1: No fault. Frames: [3, 5, 1]
# Page 2: Fault occurred. Frames: [5, 1, 2]
# Page 5: No fault. Frames: [5, 1, 2]
# Page 4: Fault occurred. Frames: [1, 2, 4]
# Page 3: Fault occurred. Frames: [2, 4, 3]
# Page 2: No fault. Frames: [2, 4, 3]
# Page 1: Fault occurred. Frames: [4, 3, 1]
# Page 2: Fault occurred. Frames: [3, 1, 2]
# Page 5: Fault occurred. Frames: [1, 2, 5]
# Page 4: Fault occurred. Frames: [2, 5, 4]
# Page 6: Fault occurred. Frames: [5, 4, 6]
# Page 7: Fault occurred. Frames: [4, 6, 7]
# Page 5: Fault occurred. Frames: [6, 7, 5]
# Page 4: Fault occurred. Frames: [7, 5, 4]
# Page 7: No fault. Frames: [7, 5, 4]
# Page 8: Fault occurred. Frames: [5, 4, 8]
# Page 9: Fault occurred. Frames: [4, 8, 9]
# Page 10: Fault occurred. Frames: [8, 9, 10]
# Page 5: Fault occurred. Frames: [9, 10, 5]
# Page 6: Fault occurred. Frames: [10, 5, 6]
# Page 10: No fault. Frames: [10, 5, 6]
# Page 1: Fault occurred. Frames: [5, 6, 1]
# Page 2: Fault occurred. Frames: [6, 1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Total faults for FIFO: 23
#
# --- Optimal Page Replacement with 3 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [1, 3, 5]
# Page 1: No fault. Frames: [1, 3, 5]
# Page 2: Fault occurred. Frames: [2, 3, 5]
# Page 5: No fault. Frames: [2, 3, 5]
# Page 4: Fault occurred. Frames: [2, 3, 4]
# Page 3: No fault. Frames: [2, 3, 4]
# Page 2: No fault. Frames: [2, 3, 4]
# Page 1: Fault occurred. Frames: [2, 1, 4]
# Page 2: No fault. Frames: [2, 1, 4]
# Page 5: Fault occurred. Frames: [5, 1, 4]
# Page 4: No fault. Frames: [5, 1, 4]
# Page 6: Fault occurred. Frames: [5, 6, 4]
# Page 7: Fault occurred. Frames: [5, 7, 4]
# Page 5: No fault. Frames: [5, 7, 4]
# Page 4: No fault. Frames: [5, 7, 4]
# Page 7: No fault. Frames: [5, 7, 4]
# Page 8: Fault occurred. Frames: [5, 8, 4]
# Page 9: Fault occurred. Frames: [5, 9, 4]
# Page 10: Fault occurred. Frames: [5, 10, 4]
# Page 5: No fault. Frames: [5, 10, 4]
# Page 6: Fault occurred. Frames: [6, 10, 4]
# Page 10: No fault. Frames: [6, 10, 4]
# Page 1: Fault occurred. Frames: [1, 10, 4]
# Page 2: Fault occurred. Frames: [2, 10, 4]
# Page 3: Fault occurred. Frames: [3, 10, 4]
# Total faults for Optimal: 17
#
# --- LRU Page Replacement with 4 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [2, 3, 5, 1]
# Page 5: No fault. Frames: [2, 3, 5, 1]
# Page 4: Fault occurred. Frames: [2, 4, 5, 1]
# Page 3: Fault occurred. Frames: [2, 4, 5, 3]
# Page 2: No fault. Frames: [2, 4, 5, 3]
# Page 1: Fault occurred. Frames: [2, 4, 1, 3]
# Page 2: No fault. Frames: [2, 4, 1, 3]
# Page 5: Fault occurred. Frames: [2, 5, 1, 3]
# Page 4: Fault occurred. Frames: [2, 5, 1, 4]
# Page 6: Fault occurred. Frames: [2, 5, 6, 4]
# Page 7: Fault occurred. Frames: [7, 5, 6, 4]
# Page 5: No fault. Frames: [7, 5, 6, 4]
# Page 4: No fault. Frames: [7, 5, 6, 4]
# Page 7: No fault. Frames: [7, 5, 6, 4]
# Page 8: Fault occurred. Frames: [7, 5, 8, 4]
# Page 9: Fault occurred. Frames: [7, 9, 8, 4]
# Page 10: Fault occurred. Frames: [7, 9, 8, 10]
# Page 5: Fault occurred. Frames: [5, 9, 8, 10]
# Page 6: Fault occurred. Frames: [5, 9, 6, 10]
# Page 10: No fault. Frames: [5, 9, 6, 10]
# Page 1: Fault occurred. Frames: [5, 1, 6, 10]
# Page 2: Fault occurred. Frames: [2, 1, 6, 10]
# Page 3: Fault occurred. Frames: [2, 1, 3, 10]
# Total faults for LRU: 20
#
# --- FIFO Page Replacement with 4 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [3, 5, 1, 2]
# Page 5: No fault. Frames: [3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [5, 1, 2, 4]
# Page 3: Fault occurred. Frames: [1, 2, 4, 3]
# Page 2: No fault. Frames: [1, 2, 4, 3]
# Page 1: No fault. Frames: [1, 2, 4, 3]
# Page 2: No fault. Frames: [1, 2, 4, 3]
# Page 5: Fault occurred. Frames: [2, 4, 3, 5]
# Page 4: No fault. Frames: [2, 4, 3, 5]
# Page 6: Fault occurred. Frames: [4, 3, 5, 6]
# Page 7: Fault occurred. Frames: [3, 5, 6, 7]
# Page 5: No fault. Frames: [3, 5, 6, 7]
# Page 4: Fault occurred. Frames: [5, 6, 7, 4]
# Page 7: No fault. Frames: [5, 6, 7, 4]
# Page 8: Fault occurred. Frames: [6, 7, 4, 8]
# Page 9: Fault occurred. Frames: [7, 4, 8, 9]
# Page 10: Fault occurred. Frames: [4, 8, 9, 10]
# Page 5: Fault occurred. Frames: [8, 9, 10, 5]
# Page 6: Fault occurred. Frames: [9, 10, 5, 6]
# Page 10: No fault. Frames: [9, 10, 5, 6]
# Page 1: Fault occurred. Frames: [10, 5, 6, 1]
# Page 2: Fault occurred. Frames: [5, 6, 1, 2]
# Page 3: Fault occurred. Frames: [6, 1, 2, 3]
# Total faults for FIFO: 19
#
# --- Optimal Page Replacement with 4 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [2, 3, 5, 1]
# Page 5: No fault. Frames: [2, 3, 5, 1]
# Page 4: Fault occurred. Frames: [2, 3, 4, 1]
# Page 3: No fault. Frames: [2, 3, 4, 1]
# Page 2: No fault. Frames: [2, 3, 4, 1]
# Page 1: No fault. Frames: [2, 3, 4, 1]
# Page 2: No fault. Frames: [2, 3, 4, 1]
# Page 5: Fault occurred. Frames: [2, 5, 4, 1]
# Page 4: No fault. Frames: [2, 5, 4, 1]
# Page 6: Fault occurred. Frames: [6, 5, 4, 1]
# Page 7: Fault occurred. Frames: [6, 5, 4, 7]
# Page 5: No fault. Frames: [6, 5, 4, 7]
# Page 4: No fault. Frames: [6, 5, 4, 7]
# Page 7: No fault. Frames: [6, 5, 4, 7]
# Page 8: Fault occurred. Frames: [6, 5, 8, 7]
# Page 9: Fault occurred. Frames: [6, 5, 9, 7]
# Page 10: Fault occurred. Frames: [6, 5, 10, 7]
# Page 5: No fault. Frames: [6, 5, 10, 7]
# Page 6: No fault. Frames: [6, 5, 10, 7]
# Page 10: No fault. Frames: [6, 5, 10, 7]
# Page 1: Fault occurred. Frames: [1, 5, 10, 7]
# Page 2: Fault occurred. Frames: [2, 5, 10, 7]
# Page 3: Fault occurred. Frames: [3, 5, 10, 7]
# Total faults for Optimal: 15
#
# --- LRU Page Replacement with 5 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [4, 3, 5, 1, 2]
# Page 3: No fault. Frames: [4, 3, 5, 1, 2]
# Page 2: No fault. Frames: [4, 3, 5, 1, 2]
# Page 1: No fault. Frames: [4, 3, 5, 1, 2]
# Page 2: No fault. Frames: [4, 3, 5, 1, 2]
# Page 5: No fault. Frames: [4, 3, 5, 1, 2]
# Page 4: No fault. Frames: [4, 3, 5, 1, 2]
# Page 6: Fault occurred. Frames: [4, 6, 5, 1, 2]
# Page 7: Fault occurred. Frames: [4, 6, 5, 7, 2]
# Page 5: No fault. Frames: [4, 6, 5, 7, 2]
# Page 4: No fault. Frames: [4, 6, 5, 7, 2]
# Page 7: No fault. Frames: [4, 6, 5, 7, 2]
# Page 8: Fault occurred. Frames: [4, 6, 5, 7, 8]
# Page 9: Fault occurred. Frames: [4, 9, 5, 7, 8]
# Page 10: Fault occurred. Frames: [4, 9, 10, 7, 8]
# Page 5: Fault occurred. Frames: [5, 9, 10, 7, 8]
# Page 6: Fault occurred. Frames: [5, 9, 10, 6, 8]
# Page 10: No fault. Frames: [5, 9, 10, 6, 8]
# Page 1: Fault occurred. Frames: [5, 9, 10, 6, 1]
# Page 2: Fault occurred. Frames: [5, 2, 10, 6, 1]
# Page 3: Fault occurred. Frames: [3, 2, 10, 6, 1]
# Total faults for LRU: 16
#
# --- FIFO Page Replacement with 5 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [3, 5, 1, 2, 4]
# Page 3: No fault. Frames: [3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [3, 5, 1, 2, 4]
# Page 1: No fault. Frames: [3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [3, 5, 1, 2, 4]
# Page 5: No fault. Frames: [3, 5, 1, 2, 4]
# Page 4: No fault. Frames: [3, 5, 1, 2, 4]
# Page 6: Fault occurred. Frames: [5, 1, 2, 4, 6]
# Page 7: Fault occurred. Frames: [1, 2, 4, 6, 7]
# Page 5: Fault occurred. Frames: [2, 4, 6, 7, 5]
# Page 4: No fault. Frames: [2, 4, 6, 7, 5]
# Page 7: No fault. Frames: [2, 4, 6, 7, 5]
# Page 8: Fault occurred. Frames: [4, 6, 7, 5, 8]
# Page 9: Fault occurred. Frames: [6, 7, 5, 8, 9]
# Page 10: Fault occurred. Frames: [7, 5, 8, 9, 10]
# Page 5: No fault. Frames: [7, 5, 8, 9, 10]
# Page 6: Fault occurred. Frames: [5, 8, 9, 10, 6]
# Page 10: No fault. Frames: [5, 8, 9, 10, 6]
# Page 1: Fault occurred. Frames: [8, 9, 10, 6, 1]
# Page 2: Fault occurred. Frames: [9, 10, 6, 1, 2]
# Page 3: Fault occurred. Frames: [10, 6, 1, 2, 3]
# Total faults for FIFO: 16
#
# --- Optimal Page Replacement with 5 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [4, 3, 5, 1, 2]
# Page 3: No fault. Frames: [4, 3, 5, 1, 2]
# Page 2: No fault. Frames: [4, 3, 5, 1, 2]
# Page 1: No fault. Frames: [4, 3, 5, 1, 2]
# Page 2: No fault. Frames: [4, 3, 5, 1, 2]
# Page 5: No fault. Frames: [4, 3, 5, 1, 2]
# Page 4: No fault. Frames: [4, 3, 5, 1, 2]
# Page 6: Fault occurred. Frames: [4, 6, 5, 1, 2]
# Page 7: Fault occurred. Frames: [4, 6, 5, 1, 7]
# Page 5: No fault. Frames: [4, 6, 5, 1, 7]
# Page 4: No fault. Frames: [4, 6, 5, 1, 7]
# Page 7: No fault. Frames: [4, 6, 5, 1, 7]
# Page 8: Fault occurred. Frames: [8, 6, 5, 1, 7]
# Page 9: Fault occurred. Frames: [9, 6, 5, 1, 7]
# Page 10: Fault occurred. Frames: [10, 6, 5, 1, 7]
# Page 5: No fault. Frames: [10, 6, 5, 1, 7]
# Page 6: No fault. Frames: [10, 6, 5, 1, 7]
# Page 10: No fault. Frames: [10, 6, 5, 1, 7]
# Page 1: No fault. Frames: [10, 6, 5, 1, 7]
# Page 2: Fault occurred. Frames: [2, 6, 5, 1, 7]
# Page 3: Fault occurred. Frames: [3, 6, 5, 1, 7]
# Total faults for Optimal: 13
#
# --- LRU Page Replacement with 6 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [0, 3, 5, 1, 2, 4]
# Page 3: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 1: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 4: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 6: Fault occurred. Frames: [6, 3, 5, 1, 2, 4]
# Page 7: Fault occurred. Frames: [6, 7, 5, 1, 2, 4]
# Page 5: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 4: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 7: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 8: Fault occurred. Frames: [6, 7, 5, 8, 2, 4]
# Page 9: Fault occurred. Frames: [6, 7, 5, 8, 9, 4]
# Page 10: Fault occurred. Frames: [10, 7, 5, 8, 9, 4]
# Page 5: No fault. Frames: [10, 7, 5, 8, 9, 4]
# Page 6: Fault occurred. Frames: [10, 7, 5, 8, 9, 6]
# Page 10: No fault. Frames: [10, 7, 5, 8, 9, 6]
# Page 1: Fault occurred. Frames: [10, 1, 5, 8, 9, 6]
# Page 2: Fault occurred. Frames: [10, 1, 5, 2, 9, 6]
# Page 3: Fault occurred. Frames: [10, 1, 5, 2, 3, 6]
# Total faults for LRU: 15
#
# --- FIFO Page Replacement with 6 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [0, 3, 5, 1, 2, 4]
# Page 3: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 1: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 4: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 6: Fault occurred. Frames: [3, 5, 1, 2, 4, 6]
# Page 7: Fault occurred. Frames: [5, 1, 2, 4, 6, 7]
# Page 5: No fault. Frames: [5, 1, 2, 4, 6, 7]
# Page 4: No fault. Frames: [5, 1, 2, 4, 6, 7]
# Page 7: No fault. Frames: [5, 1, 2, 4, 6, 7]
# Page 8: Fault occurred. Frames: [1, 2, 4, 6, 7, 8]
# Page 9: Fault occurred. Frames: [2, 4, 6, 7, 8, 9]
# Page 10: Fault occurred. Frames: [4, 6, 7, 8, 9, 10]
# Page 5: Fault occurred. Frames: [6, 7, 8, 9, 10, 5]
# Page 6: No fault. Frames: [6, 7, 8, 9, 10, 5]
# Page 10: No fault. Frames: [6, 7, 8, 9, 10, 5]
# Page 1: Fault occurred. Frames: [7, 8, 9, 10, 5, 1]
# Page 2: Fault occurred. Frames: [8, 9, 10, 5, 1, 2]
# Page 3: Fault occurred. Frames: [9, 10, 5, 1, 2, 3]
# Total faults for FIFO: 15
#
# --- Optimal Page Replacement with 6 frames ---
# Page 0: Fault occurred. Frames: [0]
# Page 3: Fault occurred. Frames: [0, 3]
# Page 5: Fault occurred. Frames: [0, 3, 5]
# Page 1: Fault occurred. Frames: [0, 3, 5, 1]
# Page 1: No fault. Frames: [0, 3, 5, 1]
# Page 2: Fault occurred. Frames: [0, 3, 5, 1, 2]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2]
# Page 4: Fault occurred. Frames: [0, 3, 5, 1, 2, 4]
# Page 3: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 1: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 2: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 5: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 4: No fault. Frames: [0, 3, 5, 1, 2, 4]
# Page 6: Fault occurred. Frames: [6, 3, 5, 1, 2, 4]
# Page 7: Fault occurred. Frames: [6, 7, 5, 1, 2, 4]
# Page 5: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 4: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 7: No fault. Frames: [6, 7, 5, 1, 2, 4]
# Page 8: Fault occurred. Frames: [6, 8, 5, 1, 2, 4]
# Page 9: Fault occurred. Frames: [6, 9, 5, 1, 2, 4]
# Page 10: Fault occurred. Frames: [6, 10, 5, 1, 2, 4]
# Page 5: No fault. Frames: [6, 10, 5, 1, 2, 4]
# Page 6: No fault. Frames: [6, 10, 5, 1, 2, 4]
# Page 10: No fault. Frames: [6, 10, 5, 1, 2, 4]
# Page 1: No fault. Frames: [6, 10, 5, 1, 2, 4]
# Page 2: No fault. Frames: [6, 10, 5, 1, 2, 4]
# Page 3: Fault occurred. Frames: [3, 10, 5, 1, 2, 4]
# Total faults for Optimal: 12
#
# Summary of Page Faults:
#    Frames  LRU Faults  FIFO Faults  Optimal Faults
# 0       1          27           27              27
# 1       2          26           26              21
# 2       3          23           23              17
# 3       4          20           19              15
# 4       5          16           16              13
# 5       6          15           15              12
# --- LRU Page Replacement with 1 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 4: Fault occurred. Frames: [4]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 7: Fault occurred. Frames: [7]
# Page 6: Fault occurred. Frames: [6]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 6: Fault occurred. Frames: [6]
# Total faults for LRU: 20
#
# --- FIFO Page Replacement with 1 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 4: Fault occurred. Frames: [4]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 7: Fault occurred. Frames: [7]
# Page 6: Fault occurred. Frames: [6]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 6: Fault occurred. Frames: [6]
# Total faults for FIFO: 20
#
# --- Optimal Page Replacement with 1 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 4: Fault occurred. Frames: [4]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 5: Fault occurred. Frames: [5]
# Page 6: Fault occurred. Frames: [6]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 7: Fault occurred. Frames: [7]
# Page 6: Fault occurred. Frames: [6]
# Page 3: Fault occurred. Frames: [3]
# Page 2: Fault occurred. Frames: [2]
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [2]
# Page 3: Fault occurred. Frames: [3]
# Page 6: Fault occurred. Frames: [6]
# Total faults for Optimal: 20
#
# --- LRU Page Replacement with 2 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 4: Fault occurred. Frames: [3, 4]
# Page 2: Fault occurred. Frames: [2, 4]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 5: Fault occurred. Frames: [5, 1]
# Page 6: Fault occurred. Frames: [5, 6]
# Page 2: Fault occurred. Frames: [2, 6]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 2: No fault. Frames: [2, 1]
# Page 3: Fault occurred. Frames: [2, 3]
# Page 7: Fault occurred. Frames: [7, 3]
# Page 6: Fault occurred. Frames: [7, 6]
# Page 3: Fault occurred. Frames: [3, 6]
# Page 2: Fault occurred. Frames: [3, 2]
# Page 1: Fault occurred. Frames: [1, 2]
# Page 2: No fault. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 6: Fault occurred. Frames: [3, 6]
# Total faults for LRU: 18
#
# --- FIFO Page Replacement with 2 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [2, 3]
# Page 4: Fault occurred. Frames: [3, 4]
# Page 2: Fault occurred. Frames: [4, 2]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 5: Fault occurred. Frames: [1, 5]
# Page 6: Fault occurred. Frames: [5, 6]
# Page 2: Fault occurred. Frames: [6, 2]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 2: No fault. Frames: [2, 1]
# Page 3: Fault occurred. Frames: [1, 3]
# Page 7: Fault occurred. Frames: [3, 7]
# Page 6: Fault occurred. Frames: [7, 6]
# Page 3: Fault occurred. Frames: [6, 3]
# Page 2: Fault occurred. Frames: [3, 2]
# Page 1: Fault occurred. Frames: [2, 1]
# Page 2: No fault. Frames: [2, 1]
# Page 3: Fault occurred. Frames: [1, 3]
# Page 6: Fault occurred. Frames: [3, 6]
# Total faults for FIFO: 18
#
# --- Optimal Page Replacement with 2 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 4: Fault occurred. Frames: [4, 2]
# Page 2: No fault. Frames: [4, 2]
# Page 1: Fault occurred. Frames: [1, 2]
# Page 5: Fault occurred. Frames: [5, 2]
# Page 6: Fault occurred. Frames: [6, 2]
# Page 2: No fault. Frames: [6, 2]
# Page 1: Fault occurred. Frames: [1, 2]
# Page 2: No fault. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 7: Fault occurred. Frames: [3, 7]
# Page 6: Fault occurred. Frames: [3, 6]
# Page 3: No fault. Frames: [3, 6]
# Page 2: Fault occurred. Frames: [3, 2]
# Page 1: Fault occurred. Frames: [1, 2]
# Page 2: No fault. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [3, 2]
# Page 6: Fault occurred. Frames: [6, 2]
# Total faults for Optimal: 15
#
# --- LRU Page Replacement with 3 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [4, 2, 3]
# Page 2: No fault. Frames: [4, 2, 3]
# Page 1: Fault occurred. Frames: [4, 2, 1]
# Page 5: Fault occurred. Frames: [5, 2, 1]
# Page 6: Fault occurred. Frames: [5, 6, 1]
# Page 2: Fault occurred. Frames: [5, 6, 2]
# Page 1: Fault occurred. Frames: [1, 6, 2]
# Page 2: No fault. Frames: [1, 6, 2]
# Page 3: Fault occurred. Frames: [1, 3, 2]
# Page 7: Fault occurred. Frames: [7, 3, 2]
# Page 6: Fault occurred. Frames: [7, 3, 6]
# Page 3: No fault. Frames: [7, 3, 6]
# Page 2: Fault occurred. Frames: [2, 3, 6]
# Page 1: Fault occurred. Frames: [2, 3, 1]
# Page 2: No fault. Frames: [2, 3, 1]
# Page 3: No fault. Frames: [2, 3, 1]
# Page 6: Fault occurred. Frames: [2, 3, 6]
# Total faults for LRU: 15
#
# --- FIFO Page Replacement with 3 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [2, 3, 4]
# Page 2: No fault. Frames: [2, 3, 4]
# Page 1: Fault occurred. Frames: [3, 4, 1]
# Page 5: Fault occurred. Frames: [4, 1, 5]
# Page 6: Fault occurred. Frames: [1, 5, 6]
# Page 2: Fault occurred. Frames: [5, 6, 2]
# Page 1: Fault occurred. Frames: [6, 2, 1]
# Page 2: No fault. Frames: [6, 2, 1]
# Page 3: Fault occurred. Frames: [2, 1, 3]
# Page 7: Fault occurred. Frames: [1, 3, 7]
# Page 6: Fault occurred. Frames: [3, 7, 6]
# Page 3: No fault. Frames: [3, 7, 6]
# Page 2: Fault occurred. Frames: [7, 6, 2]
# Page 1: Fault occurred. Frames: [6, 2, 1]
# Page 2: No fault. Frames: [6, 2, 1]
# Page 3: Fault occurred. Frames: [2, 1, 3]
# Page 6: Fault occurred. Frames: [1, 3, 6]
# Total faults for FIFO: 16
#
# --- Optimal Page Replacement with 3 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 4]
# Page 2: No fault. Frames: [1, 2, 4]
# Page 1: No fault. Frames: [1, 2, 4]
# Page 5: Fault occurred. Frames: [1, 2, 5]
# Page 6: Fault occurred. Frames: [1, 2, 6]
# Page 2: No fault. Frames: [1, 2, 6]
# Page 1: No fault. Frames: [1, 2, 6]
# Page 2: No fault. Frames: [1, 2, 6]
# Page 3: Fault occurred. Frames: [3, 2, 6]
# Page 7: Fault occurred. Frames: [3, 7, 6]
# Page 6: No fault. Frames: [3, 7, 6]
# Page 3: No fault. Frames: [3, 7, 6]
# Page 2: Fault occurred. Frames: [3, 2, 6]
# Page 1: Fault occurred. Frames: [3, 2, 1]
# Page 2: No fault. Frames: [3, 2, 1]
# Page 3: No fault. Frames: [3, 2, 1]
# Page 6: Fault occurred. Frames: [6, 2, 1]
# Total faults for Optimal: 11
#
# --- LRU Page Replacement with 4 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 5, 4]
# Page 6: Fault occurred. Frames: [1, 2, 5, 6]
# Page 2: No fault. Frames: [1, 2, 5, 6]
# Page 1: No fault. Frames: [1, 2, 5, 6]
# Page 2: No fault. Frames: [1, 2, 5, 6]
# Page 3: Fault occurred. Frames: [1, 2, 3, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 7]
# Page 6: Fault occurred. Frames: [6, 2, 3, 7]
# Page 3: No fault. Frames: [6, 2, 3, 7]
# Page 2: No fault. Frames: [6, 2, 3, 7]
# Page 1: Fault occurred. Frames: [6, 2, 3, 1]
# Page 2: No fault. Frames: [6, 2, 3, 1]
# Page 3: No fault. Frames: [6, 2, 3, 1]
# Page 6: No fault. Frames: [6, 2, 3, 1]
# Total faults for LRU: 10
#
# --- FIFO Page Replacement with 4 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [3, 4, 5, 6]
# Page 2: Fault occurred. Frames: [4, 5, 6, 2]
# Page 1: Fault occurred. Frames: [5, 6, 2, 1]
# Page 2: No fault. Frames: [5, 6, 2, 1]
# Page 3: Fault occurred. Frames: [6, 2, 1, 3]
# Page 7: Fault occurred. Frames: [2, 1, 3, 7]
# Page 6: Fault occurred. Frames: [1, 3, 7, 6]
# Page 3: No fault. Frames: [1, 3, 7, 6]
# Page 2: Fault occurred. Frames: [3, 7, 6, 2]
# Page 1: Fault occurred. Frames: [7, 6, 2, 1]
# Page 2: No fault. Frames: [7, 6, 2, 1]
# Page 3: Fault occurred. Frames: [6, 2, 1, 3]
# Page 6: No fault. Frames: [6, 2, 1, 3]
# Total faults for FIFO: 14
#
# --- Optimal Page Replacement with 4 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 6]
# Page 2: No fault. Frames: [1, 2, 3, 6]
# Page 1: No fault. Frames: [1, 2, 3, 6]
# Page 2: No fault. Frames: [1, 2, 3, 6]
# Page 3: No fault. Frames: [1, 2, 3, 6]
# Page 7: Fault occurred. Frames: [7, 2, 3, 6]
# Page 6: No fault. Frames: [7, 2, 3, 6]
# Page 3: No fault. Frames: [7, 2, 3, 6]
# Page 2: No fault. Frames: [7, 2, 3, 6]
# Page 1: Fault occurred. Frames: [1, 2, 3, 6]
# Page 2: No fault. Frames: [1, 2, 3, 6]
# Page 3: No fault. Frames: [1, 2, 3, 6]
# Page 6: No fault. Frames: [1, 2, 3, 6]
# Total faults for Optimal: 8
#
# --- LRU Page Replacement with 5 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 6, 4, 5]
# Page 2: No fault. Frames: [1, 2, 6, 4, 5]
# Page 1: No fault. Frames: [1, 2, 6, 4, 5]
# Page 2: No fault. Frames: [1, 2, 6, 4, 5]
# Page 3: Fault occurred. Frames: [1, 2, 6, 3, 5]
# Page 7: Fault occurred. Frames: [1, 2, 6, 3, 7]
# Page 6: No fault. Frames: [1, 2, 6, 3, 7]
# Page 3: No fault. Frames: [1, 2, 6, 3, 7]
# Page 2: No fault. Frames: [1, 2, 6, 3, 7]
# Page 1: No fault. Frames: [1, 2, 6, 3, 7]
# Page 2: No fault. Frames: [1, 2, 6, 3, 7]
# Page 3: No fault. Frames: [1, 2, 6, 3, 7]
# Page 6: No fault. Frames: [1, 2, 6, 3, 7]
# Total faults for LRU: 8
#
# --- FIFO Page Replacement with 5 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [2, 3, 4, 5, 6]
# Page 1: Fault occurred. Frames: [3, 4, 5, 6, 1]
# Page 2: Fault occurred. Frames: [4, 5, 6, 1, 2]
# Page 3: Fault occurred. Frames: [5, 6, 1, 2, 3]
# Page 7: Fault occurred. Frames: [6, 1, 2, 3, 7]
# Page 6: No fault. Frames: [6, 1, 2, 3, 7]
# Page 3: No fault. Frames: [6, 1, 2, 3, 7]
# Page 2: No fault. Frames: [6, 1, 2, 3, 7]
# Page 1: No fault. Frames: [6, 1, 2, 3, 7]
# Page 2: No fault. Frames: [6, 1, 2, 3, 7]
# Page 3: No fault. Frames: [6, 1, 2, 3, 7]
# Page 6: No fault. Frames: [6, 1, 2, 3, 7]
# Total faults for FIFO: 10
#
# --- Optimal Page Replacement with 5 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 6, 5]
# Page 2: No fault. Frames: [1, 2, 3, 6, 5]
# Page 1: No fault. Frames: [1, 2, 3, 6, 5]
# Page 2: No fault. Frames: [1, 2, 3, 6, 5]
# Page 3: No fault. Frames: [1, 2, 3, 6, 5]
# Page 7: Fault occurred. Frames: [1, 2, 3, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 6, 7]
# Page 1: No fault. Frames: [1, 2, 3, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 6, 7]
# Total faults for Optimal: 7
#
# --- LRU Page Replacement with 6 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 7, 5, 6]
# Page 6: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 6: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Total faults for LRU: 7
#
# --- FIFO Page Replacement with 6 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [2, 3, 4, 5, 6, 7]
# Page 1: Fault occurred. Frames: [3, 4, 5, 6, 7, 1]
# Page 2: Fault occurred. Frames: [4, 5, 6, 7, 1, 2]
# Page 3: Fault occurred. Frames: [5, 6, 7, 1, 2, 3]
# Page 6: No fault. Frames: [5, 6, 7, 1, 2, 3]
# Total faults for FIFO: 10
#
# --- Optimal Page Replacement with 6 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 7, 5, 6]
# Page 6: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Page 6: No fault. Frames: [1, 2, 3, 7, 5, 6]
# Total faults for Optimal: 7
#
# --- LRU Page Replacement with 7 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Total faults for LRU: 7
#
# --- FIFO Page Replacement with 7 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Total faults for FIFO: 7
#
# --- Optimal Page Replacement with 7 frames ---
# Page 1: Fault occurred. Frames: [1]
# Page 2: Fault occurred. Frames: [1, 2]
# Page 3: Fault occurred. Frames: [1, 2, 3]
# Page 4: Fault occurred. Frames: [1, 2, 3, 4]
# Page 2: No fault. Frames: [1, 2, 3, 4]
# Page 1: No fault. Frames: [1, 2, 3, 4]
# Page 5: Fault occurred. Frames: [1, 2, 3, 4, 5]
# Page 6: Fault occurred. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6]
# Page 7: Fault occurred. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 1: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 2: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 3: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Page 6: No fault. Frames: [1, 2, 3, 4, 5, 6, 7]
# Total faults for Optimal: 7
#
# Summary of Page Faults:
#    Frames  LRU Faults  FIFO Faults  Optimal Faults
# 0       1          20           20              20
# 1       2          18           18              15
# 2       3          15           16              11
# 3       4          10           14               8
# 4       5           8           10               7
# 5       6           7           10               7
# 6       7           7            7               7
